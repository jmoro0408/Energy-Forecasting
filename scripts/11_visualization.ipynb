# %%
from pathlib import Path

import pandas as pd

# %%
PREDS_LOAD_DIR = Path(Path.cwd().parent, "data.nosync", "outputs", "load_predictions", "prediction_2023_07_26.parquet")
VIS_SAVE_DIR = Path(Path.cwd().parent, "data.nosync", "outputs", "load_predictions", "visuals")

# %%
df = pd.read_parquet(PREDS_LOAD_DIR)

# %%
df.head()
# Out:
#   Area        Lat         Lon Grid Zone     PTID                  Lat_Lon  \
# 0  ALB  42.652580  -73.756233    CAPITL  61757.0  [42.652580, -73.756233]
# 1  ALB  42.652580  -73.756233    CAPITL  61757.0  [42.652580, -73.756233]
# 2  ALB  42.652580  -73.756233    CAPITL  61757.0  [42.652580, -73.756233]
# 3  ALB  42.652580  -73.756233    CAPITL  61757.0  [42.652580, -73.756233]
# 4  ALB  42.652580  -73.756233    CAPITL  61757.0  [42.652580, -73.756233]
#
#             Time Stamp  temp  Year  Month  ...  Min_Temp     Month_sin  \
# 0  1690329600000000000  19.7  2023      7  ...      16.5 -2.449294e-16
# 1  1690333200000000000  18.8  2023      7  ...      16.5 -2.449294e-16
# 2  1690336800000000000  18.1  2023      7  ...      16.5 -2.449294e-16
# 3  1690340400000000000  17.7  2023      7  ...      16.5 -2.449294e-16
# 4  1690344000000000000  17.3  2023      7  ...      16.5 -2.449294e-16
#
#    Month_cos   Day_sin   Day_cos  Minute_sin  Minute_cos  Hour_sin  Hour_cos  \
# ...

# %%
df['pred_load'].min()
# Out:
# 0.0
